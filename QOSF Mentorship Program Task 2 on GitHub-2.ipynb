# %% [markdown]
# # QOSF Mentorship Program Task 2

# %% [markdown]
# ## Description

# %% [markdown]
# <p style='text-align: justify;'>
# Implement a circuit that returns |01> and |10> with equal probability.
#
# Requirements :The circuit should consist only of CNOTs, RXs and RYs.
#
# Start from all parameters in parametric gates being equal to 0 or randomly chosen. You should find the right set of parameters using gradient descent (you can use more advanced optimization methods if you like).
#
# Simulations must be done with sampling (i.e. a limited number of measurements per iteration) and noise.
#
# Compare the results for different numbers of measurements: 1, 10, 100, 1000.
#
# Bonus question:
# How to make sure you produce state |01> + |10> and not |01> - |10> ?
#
# (Actually for more careful readers, the “correct” version of this question is posted below:
# How to make sure you produce state  |01⟩  +  |10⟩  and not any other combination of |01> + e(i*phi)|10⟩ (for example |01⟩  -  |10⟩)?)
# </p>

# %% [markdown]
# ## My work

# %% [markdown]
# The task tells us that we need to create a two-qubit Bell State of $\frac{1}{\sqrt(2)}(|01> + |10>)$ and not $\frac{1}{\sqrt(2)}|01> - |10>$.

# %% [markdown]
# Analytically, I try to caculate how to get to the state. I make use of the Qiksit to verfiy if my calculation is correct.

# %% [markdown]
# Numerically, we need the following:
# 1. two qubits: $q_0, q_1$
# 2. a set of operations on $R_x, R_y, CNOT$ only
# 3. Initial parameters for the gates $R_x, R_y$ corresponding to their parameters: thetaRx, thetaRy
# 4. A circuit that applies the operations to thte qubits: circuit
# 5. A simulator that runs the circuit fora specified numbdr of repetitions: reps, simulator
#
# We introdue coding Gradient Descent on Task 2 for optimized parametrized circuit using pennyLane and qiskit.

# %% [markdown]
# ### Updated version of PennyLane for circuit drawer

# %%
pip install git+https://www.github.com/XanaduAI/pennylane
# Out:
# Collecting git+https://www.github.com/XanaduAI/pennylane
#   Cloning https://www.github.com/XanaduAI/pennylane to /private/var/folders/8_/4ft2d3hn4x78_qp1dxhvkfkw0000gp/T/pip-req-build-ib8owpfk
#   Running command git clone -q https://www.github.com/XanaduAI/pennylane /private/var/folders/8_/4ft2d3hn4x78_qp1dxhvkfkw0000gp/T/pip-req-build-ib8owpfk
# Requirement already satisfied (use --upgrade to upgrade): PennyLane==0.12.0.dev0 from git+https://www.github.com/XanaduAI/pennylane in /opt/anaconda3/lib/python3.7/site-packages
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (1.18.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (1.4.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (2.4)
# Requirement already satisfied: autograd in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (1.3)
# Requirement already satisfied: toml in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (0.10.1)
# Requirement already satisfied: appdirs in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (1.4.4)
# Requirement already satisfied: semantic_version==2.6 in /opt/anaconda3/lib/python3.7/site-packages (from PennyLane==0.12.0.dev0) (2.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.7/site-packages (from networkx->PennyLane==0.12.0.dev0) (4.4.1)
# Requirement already satisfied: future>=0.15.2 in /opt/anaconda3/lib/python3.7/site-packages (from autograd->PennyLane==0.12.0.dev0) (0.18.2)
# Building wheels for collected packages: PennyLane
#   Building wheel for PennyLane (setup.py) ... done
#   Created wheel for PennyLane: filename=PennyLane-0.12.0.dev0-py3-none-any.whl size=380075 sha256=4a4b8d329bd679c0ec6a08e727f28dc1b42339efd0d2f9076fde6cdd0625dd68
#   Stored in directory: /private/var/folders/8_/4ft2d3hn4x78_qp1dxhvkfkw0000gp/T/pip-ephem-wheel-cache-enygdsky/wheels/32/61/33/bd8b8097944427dc715a31ff9c5eba18c2675e5e971ef48fcd
# Successfully built PennyLane
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in /opt/anaconda3/lib/python3.7/site-packages (2.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We have imported a variety of packages for the below coding.

# %% [markdown]
# ### Importing Packages

# %%
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit, execute
from qiskit import execute, Aer, BasicAer
from qiskit import IBMQ
from qiskit.tools.visualization import plot_histogram, plot_state_city, circuit_drawer
from qiskit.providers.aer import QasmSimulator, StatevectorSimulator, UnitarySimulator
from qiskit.quantum_info import state_fidelity
from qiskit.providers.aer.noise import NoiseModel

import pennylane as qml 
from pennylane import numpy as np

import scipy as sp
from scipy.optimize import minimize 

from math import pi
import random
import itertools
import os
from IPython.display import SVG, display
from typing import List, Union, Sequence, Dict, Optional

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl

# %% [markdown]
# # Bell State 1

# %% [markdown]
# ![IMG_2459.jpg](attachment:IMG_2459.jpg)

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.draw(output = 'mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()

# %%
print(out)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# # Bell State 2

# %% [markdown]
# ![IMG_2460.jpg](attachment:IMG_2460.jpg)

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.z(qr[0])
qc.draw(output = 'mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()

# %%
print(out)
# Out:
# [ 0.70710678+0.j -0.        +0.j  0.        +0.j -0.70710678+0.j]

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# # Bell State 3

# %% [markdown]
# ![IMG_2462.jpg](attachment:IMG_2462.jpg)

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.z(qr[0])
qc.x(qr[1])
qc.draw(output = 'mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()

# %%
print(out)
# Out:
# [ 0.        +0.j -0.70710678+0.j  0.70710678+0.j -0.        +0.j]

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# # Bell State 4

# %% [markdown]
# ![IMG_2463.jpg](attachment:IMG_2463.jpg)

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.z(qr[0])
qc.x(qr[1])
qc.z(qr[0])
qc.draw(output = 'mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()

# %%
print(out)
# Out:
# [0.        +0.j 0.70710678-0.j 0.70710678+0.j 0.        -0.j]

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# However, in this kind of operation, we see that some gates are behind the $CNOT$ gate. We try to work out all the quantum gate before $CNOT$ gate for afterwards generalization in unitary operation.

# %% [markdown]
# # The desired Bell State    $\frac{1}{\sqrt(2)}(|01>+|10>)$

# %% [markdown]
# ![IMG_2479.jpg](attachment:IMG_2479.jpg)

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.x(qr[1])
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.draw(output = 'mpl')

# %%
# Let's see the result
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()

# %%
print(out)
# Out:
# [0.        +0.j 0.70710678+0.j 0.70710678+0.j 0.        +0.j]

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# From the above circuit diagram, we need $H, Z, X, CNOT$ to make Bell State. Now we want to represent these gates in terms of unitary rotational gate, like $R_x, R_y, CNOT$. From the task requirement, we want Bell State 3, so let's work it out based one the above gates operation. First of all, we need to represent $H$ gate in terms of $R_x$ and $R_y$. I can make use of the below generalized Unitary operation formula to the representation of $H$.

# %% [markdown]
# ![IMG_2466.jpg](attachment:IMG_2466.jpg)

# %%
# Useful additional packages
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer

backend = BasicAer.get_backend('unitary_simulator')

# %%
qc = QuantumCircuit(qr)
qc.h(qr[0])
qc.draw()
# Out:
#        ┌───┐
# q34_0: ┤ H ├
#        └───┘
# q34_1: ─────

# %%
backend = BasicAer.get_backend('unitary_simulator')
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.70710678+0.00000000e+00j,  0.70710678-8.65956056e-17j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.70710678+0.00000000e+00j, -0.70710678+8.65956056e-17j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678+0.00000000e+00j,  0.70710678-8.65956056e-17j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678+0.00000000e+00j, -0.70710678+8.65956056e-17j]])

# %% [markdown]
# $$H = R_y(\frac{5\pi}{8})R_x(\pi)R_y(\frac{\pi}{8})$$

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.ry(5*pi/8, qr[0])
qc.rx(pi, qr[0]) 
qc.ry(pi/8, qr[0])
qc.draw(output='mpl')

# %%
backend = BasicAer.get_backend('unitary_simulator')
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.70710678+0.00000000e+00j,  0.70710678+2.27422886e-16j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.70710678+0.00000000e+00j, -0.70710678-2.27422886e-16j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678+0.00000000e+00j,  0.70710678+2.27422886e-16j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678+0.00000000e+00j, -0.70710678-2.27422886e-16j]])

# %% [markdown]
# Below is the previous workout that is not the optimal way to generalize the quantum circuit.

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.ry(pi/8, qr[0])
qc.rx(pi, qr[0])
qc.ry(5*pi/8, qr[0])
qc.cx(qr[0],qr[1])
qc.z(qr[0])
qc.x(qr[1])
qc.draw(output = 'mpl')

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# $$H = R_y(\frac{\pi}{4})R_x(\pi)R_y(\frac{-\pi}{4})$$

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.ry(-pi/4, qr[0])
qc.rx(pi, qr[0]) 
qc.ry(pi/4, qr[0])
qc.draw(output='mpl')

# %%
backend = BasicAer.get_backend('unitary_simulator')
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.70710678+0.00000000e+00j, -0.70710678+1.57009246e-16j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [-0.70710678-4.00614097e-16j, -0.70710678-8.65956056e-17j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678+0.00000000e+00j, -0.70710678+1.57009246e-16j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#         -0.70710678-4.00614097e-16j, -0.70710678-8.65956056e-17j]])

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.ry(pi/4, qr[0])
qc.rx(-pi, qr[0]) 
qc.ry(-pi/4, qr[0])
qc.cx(qr[0],qr[1])
qc.z(qr[0])
qc.x(qr[1])
qc.draw(output = 'mpl')

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# Although the $R_y(\frac{5\pi}{8})R_x(\pi)R_y(\frac{\pi}{8}) \neq H = R_y(\frac{\pi}{4})R_x(\pi)R_y(\frac{-\pi}{4})$ , both yields the same result of the Bell state with nearly equal probability. However, it is not the best way to represent $H$ gate.

# %% [markdown]
# # The best way for generalization

# %% [markdown]
# As later I have found another way to generalize the desired bell state by putting all the gate in front of the $CNOT$ gate, I come up with the folllowing setting with the same result.

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.ry(pi/4, qr[0])
qc.rx(-pi, qr[0]) 
qc.ry(-pi/4, qr[0])
qc.x(qr[1])
qc.cx(qr[0],qr[1])
qc.draw(output = 'mpl')

# %%
backend = BasicAer.get_backend('unitary_simulator')
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678-8.65956056e-17j,  0.70710678+0.00000000e+00j],
#        [ 0.70710678+0.00000000e+00j, -0.70710678-8.65956056e-17j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.70710678+0.00000000e+00j,  0.70710678+8.65956056e-17j,
#          0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,
#          0.70710678-8.65956056e-17j, -0.70710678+0.00000000e+00j]])

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# After a few thoughts on the unitary operation,we can use blochsphere visulziation. I think using $R_y(\pi/2)$ to represent $H$ gate is good enough. While $X$ gate is rotation the state in y-axis through $\pi$ radian.

# %% [markdown]
# ![IMG_1052FA5B00C5-1.jpeg](attachment:IMG_1052FA5B00C5-1.jpeg)

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.ry(pi/2, qr[0])
qc.ry(pi, qr[1])
qc.cx(qr[0],qr[1])
qc.draw(output = 'mpl')

# %%
backend = BasicAer.get_backend('unitary_simulator')
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.        +0.j,  0.        +0.j, -0.70710678+0.j,
#          0.70710678+0.j],
#        [ 0.70710678+0.j,  0.70710678+0.j,  0.        +0.j,
#          0.        +0.j],
#        [ 0.70710678+0.j, -0.70710678+0.j,  0.        +0.j,
#          0.        +0.j],
#        [ 0.        +0.j,  0.        +0.j, -0.70710678+0.j,
#         -0.70710678+0.j]])

# %%
qc.measure(qr,cr)
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend=backend).result()
plot_histogram(job.get_counts(qc))

# %% [markdown]
# # Quantum Machine Learning (updated from time to time)

# %% [markdown]
# The above anyltical method can definitely help us to find the bell state, in terms of various quantum gates. However, we need to do alegrbaric calculation before we can encode and verify the state. It will be time consuming if we work on more complicated quantum state that we can no longer calculate by hand. From the above unitary operation, we found that there are 4 sets of paramertrized cicuit that can be used to find the Bell State 3, however, which one should be the optimal parametrizd one? Therefore, we need a more intelligent method to help us find the desired state and now I introduce gradient descent to find the global minimum for our optimal circuit parameter.

# %% [markdown]
# ## Paramaterized Quantum Circuit

# %% [markdown]
# <p style='text-align: justify;'>
# Quantum Device, qml.device( ) is a computational object that we can apply opertaion featured in quantum mechanics, the result then returned from the measurement. Here we use the "default.qubit" to inidicate the pure state qubit simulator in pennyLane, while wires = 2 corresponds to the number of qubits, i.e. 2 for Bell state.
#     </p>

# %%
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_vigo')
noise_model = NoiseModel.from_backend(backend)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
dev = qml.device('qiskit.aer', wires = 2, shots = 1000, noise_model = noise_model)

# %% [markdown]
# *Note*:
#
# PennyLane uses the term `wires` to refer to a quantum subsystem for most devies, this corresponds to a qubit. For continous-variable devices, a wire corresponds to a quantum mode.
#
# `shots` refers to the number of evaluation of the quantum circuit to estimate the expectation values. Defaults to 1,000 if not specified.
#
# `analytic` indicates if the device should calculate expectations and variance analytically. It is only possible with simulator devices. Defaults to `True`.
# </p>

# %% [markdown]
# <p style='text-align: justify;'>
# In PennyLane, quantum computations are represented as quantum node objects. We can see below the @qml.qnode( ) are encapsulating the quantum function which is described by quantum circuit to declare it. They are bound to a particular quantum device to evaluate expectation value and varience of the circuit. By using @qml.qnode( ), we tell pennylane that the circuit is implemented on a quantum device. In the function, we apply unitary rotational gates, like $R_x$, $R_y$, $CNOT$ on the pure state $|0>$. Then we make measurement and calculate the expected value of $\sigma_z$.
#     </p>

# %%
@qml.qnode(dev, interface='autograd')

def generateCircuit(params):
    qml.RY(params[0],wires = 0) # Rx is applied with the 1st parameter, on the first qubit
    qml.RY(params[1],wires = 1) # Ry is applied with the 2nd parameter, on the first qubit
    qml.CNOT(wires = [0, 1]) # CNOT is applied on the first and second qubit
    #my_circuit(wires = (1,0))
    return qml.probs(wires=[0,1]) #qml.expval(qml.PauliZ(1))#qml.sample(qml.PauliZ('wire1')) qml.sample(qml.PauliZ('wire2'))

# %% [markdown]
# *Note*:
#
# The bridge between the quantum and classical worlds is provided in PennyLane via interfaces. There are *Numpy, PyTorch, TensorFlow* to make the libraries quantum-aware. If no interface is specified, Pennylane will default to the NumPy interface.
#
# Numpy interface provides added benefits of automatic differentiation, backpropapation of classical computations, powered by *autograd*.

# %% [markdown]
# ### Initialize the parameters

# %% [markdown]
# The parameters $\theta_1$ & $\theta_2$ are initialized. We need to check if we obtain the right unitary rotation on applying the circuit.

# %%
params =[1.570796327,1.570796327]
generateCircuit(params)
# Out:
# array([0.264, 0.234, 0.258, 0.244])

# %%
params = [0, 0]
generateCircuit(params)
# Out:
# array([0.973, 0.017, 0.01 , 0.   ])

# %%
params = [0,0.5]
generateCircuit(params)
# Out:
# array([0.91 , 0.082, 0.007, 0.001])

# %%
result = generateCircuit(params)
result.shape
# Out:
# (4,)

# %% [markdown]
# ### Draw Quantum Circuit

# %% [markdown]
# We print out the gate applied by QNode after each evaluation.

# %%
generateCircuit.print_applied()
# Out:
# Operations
# ==========
# RY(0, wires=[0])
# RY(0.5, wires=[1])
# CNOT(wires=[0, 1])
#
# Observables
# ===========
# probs(wires=[0, 1])

# %% [markdown]
# Circuit drawer can be used in the following way:

# %%
result = generateCircuit(params)
print(generateCircuit.draw())
# Out:
#  0: ──RY(0)────╭C──╭┤ Probs
#  1: ──RY(0.5)──╰X──╰┤ Probs

# %% [markdown]
# ### Defining Cost Function and initial parameters

# %% [markdown]
# The model in supervisd learing refers to the mathematical structure of by which the prediction $y_i$ is made from the input $x_i$. The prediction is given as
#
# $$\hat y_i = \sum_{j}^\ (\theta_jx_{ij})$$
#
# , which is linear combination of weighted input features. The *parameteers* are the undetermined part that we need to learn from data.
#
# The training Cost Function measures how predictive our model is with respect to the training data. A common choice of $L$ is the *mean squared error*, which is given by

# %% [markdown]
# $$L(\theta) = \sum_{i}^\ (y_i - \hat y_i)^2$$

# %% [markdown]
# As we only want Bell State 3, so the prediction value of the other states will be 0 while that of Bell State 3 will be $\frac{1}{2}$. We define the Lost Function as follow:

# %%
def cost(params):
    Bell_1, Bell_2, Bell_3, Bell_4 = generateCircuit(params)
    return ((Bell_1-0)**2 + (Bell_2-0.5)**2 + (Bell_3-0.5)**2 + (Bell_4-0)**2)

# %% [markdown]
# ### Optimizing the cost function using gradient descent

# %% [markdown]
# We use an intance of the function GradientDescentOptimizer to perform gradient descent. The hyperparameter of this optimization are step size and initial parameters. This stepsize denotes how big is the step to move every iteration.

# %% [markdown]
# A copy is needed so one cna change one copy without changning the other. THe shallow copy constrcuts a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.

# %%
prob = []
all_costs = []

for num_shots in [1, 10, 100, 1000]:
    dev.shots = num_shots
    initial_parameters = np.random.randn(2) #we need random parameters 
    
    steps = 100 # maximum the number of steps taken
    
    params = initial_parameters.copy()
    
    optimizer = qml.GradientDescentOptimizer(stepsize=0.4) # initialise the optimizer
    
    costs = []
    
    print('*'*100)
    print('For {0} shots\n'.format(num_shots))
    for i in range(steps):
        costs.append(cost(params))
        params = optimizer.step(cost, params)
        
        if (i + 1) % 5 == 0:
            print("Cost after step {:5d}: {: .7f}".format(i + 1, cost(params)))
    all_costs.append(costs)

    p = [0, 0, 0, 0]
    p[0], p[1], p[2], p[3] = generateCircuit(params)
    
    print('The parameters are {0}\n'.format(params))
    print('The probability of various states: \n')
    print('\n Probality of 00 is: {0} \n Probality of 01 is: {1} \n Probality of 10 is: {2} \n Probality of 11 is: {3}'.format(p[0], p[1], p[2], p[3]))
    
    prob.append(p)
# Out:
# ****************************************************************************************************
# For 1 shots
#
# Cost after step     5:  0.5000000
# Cost after step    10:  0.5000000
# Cost after step    15:  0.5000000
# Cost after step    20:  0.5000000
# Cost after step    25:  0.5000000
# Cost after step    30:  0.5000000
# Cost after step    35:  0.5000000
# Cost after step    40:  0.5000000
# Cost after step    45:  0.5000000
# Cost after step    50:  0.5000000
# Cost after step    55:  1.5000000
# Cost after step    60:  0.5000000
# Cost after step    65:  0.5000000
# Cost after step    70:  1.5000000
# Cost after step    75:  1.5000000
# Cost after step    80:  1.5000000
# Cost after step    85:  1.5000000
# Cost after step    90:  0.5000000
# Cost after step    95:  1.5000000
# Cost after step   100:  0.5000000
# The parameters are [ 3.2952428  -2.26071538]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.0
#  Probality of 01 is: 0.0
#  Probality of 10 is: 1.0
#  Probality of 11 is: 0.0
# ****************************************************************************************************
# For 10 shots
#
# Cost after step     5:  0.1400000
# Cost after step    10:  0.0200000
# Cost after step    15:  0.2600000
# Cost after step    20:  0.2600000
# Cost after step    25:  0.1400000
# Cost after step    30:  0.0200000
# Cost after step    35:  0.0200000
# Cost after step    40:  0.0800000
# Cost after step    45:  0.0200000
# Cost after step    50:  0.0600000
# Cost after step    55:  0.0000000
# Cost after step    60:  0.0600000
# Cost after step    65:  0.0800000
# Cost after step    70:  0.0600000
# Cost after step    75:  0.0600000
# Cost after step    80:  0.0200000
# Cost after step    85:  0.0800000
# Cost after step    90:  0.0800000
# Cost after step    95:  0.0000000
# Cost after step   100:  0.1400000
# The parameters are [ 1.52181269 -2.98483629]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.1
#  Probality of 01 is: 0.3
#  Probality of 10 is: 0.6
#  Probality of 11 is: 0.0
# ****************************************************************************************************
# For 100 shots
#
# Cost after step     5:  0.3396000
# Cost after step    10:  0.1630000
# Cost after step    15:  0.0248000
# Cost after step    20:  0.0030000
# Cost after step    25:  0.0174000
# Cost after step    30:  0.0172000
# Cost after step    35:  0.0194000
# Cost after step    40:  0.0238000
# Cost after step    45:  0.0046000
# Cost after step    50:  0.0090000
# Cost after step    55:  0.0144000
# Cost after step    60:  0.0302000
# Cost after step    65:  0.0036000
# Cost after step    70:  0.0024000
# Cost after step    75:  0.0054000
# Cost after step    80:  0.0094000
# Cost after step    85:  0.0378000
# Cost after step    90:  0.0050000
# Cost after step    95:  0.0146000
# Cost after step   100:  0.0036000
# The parameters are [-1.60079872  3.06745078]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.07
#  Probality of 01 is: 0.48
#  Probality of 10 is: 0.45
#  Probality of 11 is: 0.0
# ****************************************************************************************************
# For 1000 shots
#
# Cost after step     5:  0.4835860
# Cost after step    10:  0.1030940
# Cost after step    15:  0.0277860
# Cost after step    20:  0.0143920
# Cost after step    25:  0.0142060
# Cost after step    30:  0.0082380
# Cost after step    35:  0.0052620
# Cost after step    40:  0.0062140
# Cost after step    45:  0.0055820
# Cost after step    50:  0.0057540
# Cost after step    55:  0.0030220
# Cost after step    60:  0.0038540
# Cost after step    65:  0.0035540
# Cost after step    70:  0.0022700
# Cost after step    75:  0.0031260
# Cost after step    80:  0.0051500
# Cost after step    85:  0.0042980
# Cost after step    90:  0.0035540
# Cost after step    95:  0.0029420
# Cost after step   100:  0.0048740
# The parameters are [-1.56224417  3.05204866]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.032
#  Probality of 01 is: 0.441
#  Probality of 10 is: 0.518
#  Probality of 11 is: 0.009

# %%
plt.bar(['00','01','10', '11'], prob[0]) #Probability Distribution for shots 1
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['00','01','10', '11'], prob[1]) #Probability Distribution for shots 10
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['00','01','10', '11'], prob[2])  #Probability Distribution for shots 100
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['00','01','10', '11'], prob[3])  #Probability Distribution for shots 1000
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # For Simulation without Noise

# %% [markdown]
# We simply use the previous wihtout the noise model implemetning to the device.

# %%
dev = qml.device('qiskit.aer', wires = 2, shots = 1000)

# %%
@qml.qnode(dev, interface='autograd')

def generateCircuit(params):
    qml.RY(params[0],wires = 0) # Rx is applied with the 1st parameter, on the first qubit
    qml.RY(params[1],wires = 1) # Ry is applied with the 2nd parameter, on the first qubit
    qml.CNOT(wires = [0, 1]) # CNOT is applied on the first and second qubit
    #my_circuit(wires = (1,0))
    return qml.probs(wires=[0,1]) #qml.expval(qml.PauliZ(1))#qml.sample(qml.PauliZ('wire1')) qml.sample(qml.PauliZ('wire2'))

# %%
def cost(params):
    Bell_1, Bell_2, Bell_3, Bell_4 = generateCircuit(params)
    return ((Bell_1-0)**2 + (Bell_2-0.5)**2 + (Bell_3-0.5)**2 + (Bell_4-0)**2)

# %%
prob = []
all_costs = []

for num_shots in [1, 10, 100, 1000]:
    dev.shots = num_shots
    initial_parameters = np.random.randn(2) #we need random parameters 
    
    steps = 100 # maximum the number of steps taken
    
    params = initial_parameters.copy()
    
    optimizer = qml.GradientDescentOptimizer(stepsize=0.4) # initialise the optimizer
    
    costs = []
    
    print('*'*110)
    print('For {0} shots\n'.format(num_shots))
    for i in range(steps):
        costs.append(cost(params))
        params = optimizer.step(cost, params)
        
        if (i + 1) % 5 == 0:
            print("Cost after step {:5d}: {: .7f}".format(i + 1, cost(params)))
    all_costs.append(costs)

    p = [0, 0, 0, 0]
    p[0], p[1], p[2], p[3] = generateCircuit(params)
    
    print('The parameters are {0}\n'.format(params))
    print('The probability of various states: \n')
    print('\n Probality of 00 is: {0} \n Probality of 01 is: {1} \n Probality of 10 is: {2} \n Probality of 11 is: {3}'.format(p[0], p[1], p[2], p[3]))
    
    prob.append(p)
# Out:
# **************************************************************************************************************
# For 1 shots
#
# Cost after step     5:  0.5000000
# Cost after step    10:  0.5000000
# Cost after step    15:  0.5000000
# Cost after step    20:  1.5000000
# Cost after step    25:  0.5000000
# Cost after step    30:  0.5000000
# Cost after step    35:  0.5000000
# Cost after step    40:  0.5000000
# Cost after step    45:  0.5000000
# Cost after step    50:  0.5000000
# Cost after step    55:  0.5000000
# Cost after step    60:  1.5000000
# Cost after step    65:  1.5000000
# Cost after step    70:  0.5000000
# Cost after step    75:  0.5000000
# Cost after step    80:  0.5000000
# Cost after step    85:  0.5000000
# Cost after step    90:  0.5000000
# Cost after step    95:  0.5000000
# Cost after step   100:  0.5000000
# The parameters are [4.88734798 3.3166947 ]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.0
#  Probality of 01 is: 1.0
#  Probality of 10 is: 0.0
#  Probality of 11 is: 0.0
# **************************************************************************************************************
# For 10 shots
#
# Cost after step     5:  0.2200000
# Cost after step    10:  0.0600000
# Cost after step    15:  0.0800000
# Cost after step    20:  0.0800000
# Cost after step    25:  0.1800000
# Cost after step    30:  0.0200000
# Cost after step    35:  0.0200000
# Cost after step    40:  0.0200000
# Cost after step    45:  0.0000000
# Cost after step    50:  0.0600000
# Cost after step    55:  0.0200000
# Cost after step    60:  0.0200000
# Cost after step    65:  0.0200000
# Cost after step    70:  0.0800000
# Cost after step    75:  0.0800000
# Cost after step    80:  0.0800000
# Cost after step    85:  0.1800000
# Cost after step    90:  0.0200000
# Cost after step    95:  0.3200000
# Cost after step   100:  0.0000000
# The parameters are [ 1.55496442 -2.95074213]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.0
#  Probality of 01 is: 0.3
#  Probality of 10 is: 0.7
#  Probality of 11 is: 0.0
# **************************************************************************************************************
# For 100 shots
#
# Cost after step     5:  0.3402000
# Cost after step    10:  0.0482000
# Cost after step    15:  0.0182000
# Cost after step    20:  0.0094000
# Cost after step    25:  0.0200000
# Cost after step    30:  0.0236000
# Cost after step    35:  0.0034000
# Cost after step    40:  0.0086000
# Cost after step    45:  0.0034000
# Cost after step    50:  0.0026000
# Cost after step    55:  0.0146000
# Cost after step    60:  0.0018000
# Cost after step    65:  0.0548000
# Cost after step    70:  0.0034000
# Cost after step    75:  0.0036000
# Cost after step    80:  0.0246000
# Cost after step    85:  0.0050000
# Cost after step    90:  0.0132000
# Cost after step    95:  0.0000000
# Cost after step   100:  0.0002000
# The parameters are [1.60398038 2.91583195]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.0
#  Probality of 01 is: 0.55
#  Probality of 10 is: 0.44
#  Probality of 11 is: 0.01
# **************************************************************************************************************
# For 1000 shots
#
# Cost after step     5:  0.0600140
# Cost after step    10:  0.0147060
# Cost after step    15:  0.0066060
# Cost after step    20:  0.0048820
# Cost after step    25:  0.0046700
# Cost after step    30:  0.0031500
# Cost after step    35:  0.0015560
# Cost after step    40:  0.0005040
# Cost after step    45:  0.0011860
# Cost after step    50:  0.0025300
# Cost after step    55:  0.0006140
# Cost after step    60:  0.0012900
# Cost after step    65:  0.0002660
# Cost after step    70:  0.0006220
# Cost after step    75:  0.0003420
# Cost after step    80:  0.0007220
# Cost after step    85:  0.0004560
# Cost after step    90:  0.0002900
# Cost after step    95:  0.0013860
# Cost after step   100:  0.0012940
# The parameters are [-1.572459    2.91320732]
#
# The probability of various states:
#
#
#  Probality of 00 is: 0.007
#  Probality of 01 is: 0.49
#  Probality of 10 is: 0.497
#  Probality of 11 is: 0.006

# %%
plt.bar(['00','01','10', '11'], prob[0]) #Probability Distribution for shots 1
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['00','01','10', '11'], prob[1]) #Probability Distribution for shots 10
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['00','01','10', '11'], prob[2])  #Probability Distribution for shots 100
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['00','01','10', '11'], prob[3])  #Probability Distribution for shots 1000
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# It is found that the proabaility of $|01>$ & $|10>$ increaes with the number of shots. Besides, the probability is higher in noiseless simulation than that in noise one. We observe that $|00>$ and $|11>$ can be measured with very few occasion.

# %% [markdown]
# # Reference:
#
# ## On Pennylane
# 1. Gradient Descent
# https://rohithkrishna.in/2020-09-11-qubit-rotation-gradient-descent
# https://medium.com/@dhartidhami/machine-learning-basics-model-cost-function-and-gradient-descent-79b69ff28091
# https://www.kdnuggets.com/2020/05/5-concepts-gradient-descent-cost-function.html
# https://rohithkrishna.in/files/pdf/2020-09-11-qubit-rotation-gradient-descent.pdf
# https://medium.com/@lachlanmiller_52885/machine-learning-week-1-cost-function-gradient-descent-and-univariate-linear-regression-8f5fe69815fd
# https://ml-cheatsheet.readthedocs.io/en/latest/gradient_descent.html
# http://kronosapiens.github.io/blog/2017/03/28/objective-functions-in-machine-learning.html
# https://www.youtube.com/watch?v=wWQL2vJoIx8
# https://xgboost.readthedocs.io/en/latest/tutorials/model.html
# https://www.youtube.com/watch?v=9nVbBGi-jfM
#
# 2. qml documentation
# https://pennylane.readthedocs.io/en/stable/code/qml.html
# 3. Presentation
# https://av.tib.eu/media/44477
# 4. Quantum Circuit Structural Learning
# https://pennylane.ai/qml/demos/tutorial_rotoselect.html
# 5. Quantum Circuit
# https://pennylane.readthedocs.io/en/stable/introduction/circuits.html
# 6. Advanced Usage
# https://pennylane.ai/qml/demos/tutorial_advanced_usage.html
#
# ## On Github Resource
# 1. Bell State Generation
# https://github.com/amitjamadagni/QCM/blob/master/Bell_state_generation.ipynb
# 2. Vanilla Gradient Descent and Quantum Natural Gradient Descent
# https://github.com/hsim13372/quantum_natural_gradient/blob/master/single_qubit_vqe/single_qubit_rotations.ipynb
# 3. Entanglement
# https://github.com/kelzheng/QC-Mentorship/blob/master/QC_Mentorship.ipynb
# 4. Determine the lowest eigenvalue of the matrix using the variational quantum eigensolver method https://github.com/OscarJHernandez/qc_mentorship_task/blob/master/QC-Mentorship%20Assignment.ipynb
# 5. Awesome Quantum Machine Learning
# https://github.com/krishnakumarsekar/awesome-quantum-machine-learning#introduction-why-quantum-machine-learning
#
# ## On Qiskit
# 1. qml.from_qiskit
# https://pennylane.readthedocs.io/en/stable/_modules/pennylane/io.html#from_qiskit
# 2. Hybrid quantum-classical Neural Networks with PyTorch and Qiskit
# https://qiskit.org/textbook/ch-machine-learning/machine-learning-qiskit-pytorch.html
# 3. Qiskit Aer simulator backends
# https://qiskit.org/documentation/tutorials/simulators/1_aer_provider.html
# 4. Analytic Quantum Gradient Descent (AQGD) optimizer
# https://qiskit.org/documentation/stubs/qiskit.aqua.components.optimizers.AQGD.html
# 5. Source code for qiskit.aqua.components.optimizers
# https://qiskit.org/documentation/_modules/qiskit/aqua/components/optimizers/aqgd.html
# 6. Qiskit Visualizations
# https://qiskit.org/documentation/tutorials/circuits/2_plotting_data_in_qiskit.html
# 7. Source code for qiskit.optimization.algorithms.recursive_minimum_eigen_optimizer
# https://qiskit.org/documentation/_modules/qiskit/optimization/algorithms/recursive_minimum_eigen_optimizer.html
# 8. Adding quantum gradient descent class aqgd
# https://github.com/Qiskit/qiskit-aqua/pull/408
# 9. Optimizier
# https://sooluthomas.github.io/testTranslation/aqua/optimizers.html
# 10. How to implement the 4 Bell states on the IBM Q (composer)?
# https://quantumcomputing.stackexchange.com/questions/2258/how-to-implement-the-4-bell-states-on-the-ibm-q-composer
# 11. Single Qubit Gate
# https://qiskit.org/textbook/ch-states/single-qubit-gates.html
#
# ## Research Paper
# 1. Efficient evaluation of quantum observables using entangled measurements
# https://www.nature.com/articles/s41534-020-0284-2
# 2. Quantum Circuit Learning
# https://arxiv.org/pdf/1803.00745.pdf
# 3. Evaluating analytic gradients on quantum hardware
# https://arxiv.org/pdf/1811.11184.pdf
#
# ## On Python Knowledge
# 1. arg num
# https://pymbook.readthedocs.io/en/latest/modules.html
# 2. Argument Definition
# https://www.geeksforgeeks.org/args-kwargs-python/
# 3, copy
# https://docs.python.org/3/library/copy.html
#
# ## On Jupyter Notebook and Latex
# 1. Draw Quantum Circuit
# https://discuss.pennylane.ai/t/any-way-to-draw-my-quantum-circuit/290
# 2. Alignment in Markdown Text
# https://stackoverflow.com/questions/35077507/how-to-right-align-and-justify-align-in-markdown/43070925
# 3. Format text in Jypter Notebook with Markdown
# https://www.earthdatascience.org/courses/intro-to-earth-data-science/file-formats/use-text-files/format-text-with-markdown-jupyter-notebook/
# 4. Double Subscript
# https://www.overleaf.com/learn/latex/Errors/Double_subscript
#
# ## My Enquiry on PennyLane Forum
# 1. Optimiziation Error:
# https://discuss.pennylane.ai/t/optimization-error/109/3
# 2. Combined measurement results and error on numpy
# https://discuss.pennylane.ai/t/combined-measurement-results-and-error-on-numpy/595
# 3. ‘function’ object has no attribute ‘PauliZ
# https://discuss.pennylane.ai/t/function-object-has-no-attribute-pauliz/279
# 4. Gradient Descent of real scalar-output function
# https://discuss.pennylane.ai/t/gradient-descent-of-real-scalar-output-function/596
# 5. Problem with printing the result with the parameter naming: ‘Variable’ object is not subscriptable
# https://discuss.pennylane.ai/t/problem-with-printing-the-result-with-the-parameter-naming-variable-object-is-not-subscriptable/598
#
# ## QC Mentorship Program
# 1. https://docs.google.com/document/d/1Ow3v8Y4rYBdgxXNxKV9ZUAM4bwL6211U6DWCcByZ4A4/edit
# 2. https://docs.google.com/forms/d/e/1FAIpQLSeof4roYaazG9v4u7_vHKWsSmqnpzOECzRvvMtpDuAepB_R5A/viewform
# 3. https://docs.google.com/document/d/1lo_qy6Y7jhwBMWpQuecxAFG3L_4soYkpq0TaLq42o-A/edit
# 4. https://qosf.org/cohort_1/
#
# ## In General
# 1. But what is a Neural Network? | Deep learning, chapter 1
# https://www.youtube.com/watch?v=aircAruvnKk&t=22s
# 2. Feedforward Neural Network https://en.wikipedia.org/wiki/Feedforward_neural_network
#
# 2. Quantum Computing Overview
# https://www.phmsociety.org/sites/phmsociety.org/files/Keynote_Dr.%20Sunil%20Dixit%20QC%20Presentation%20PHM%20Society%202018.pdf
# 3. Quanutm Computing Coding
# http://www-users.cselabs.umn.edu/classes/Spring-2020/csci5451/FILES/LecN19_R.pdf
# 4. Two Qubit Entanglement and Bell Inequalities
# https://inst.eecs.berkeley.edu/~cs191/fa08/lectures/lecture2.pdf
# 5. Resource on Quanutm Information and Processing
# https://viterbi-web.usc.edu/~tbrun/
# 6. Gates for a single qubit
# http://math.utoledo.edu/~codenth/Spring_15/4350/HW/hw05.pdf
